# %% [markdown]
# <a href="https://colab.research.google.com/github/HugoLeda/ML-Olympiad-Toxic-Language-PTBR-Detection/blob/main/Pre_processamento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import re

# %%
# !pip install wget
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9656 sha256=2aaaf75342e2294a2093e639bedbcb0420dbb3bfe6eca583478309625ca41afd
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# ...

# %%
# !wget https://raw.githubusercontent.com/HugoLeda/ML-Olympiad-Toxic-Language-PTBR-Detection/main/assets/train.csv
# Out:
# --2024-05-23 02:14:00--  https://raw.githubusercontent.com/HugoLeda/ML-Olympiad-Toxic-Language-PTBR-Detection/main/assets/train.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1573871 (1.5M) [text/plain]
# Saving to: ‘train.csv’
#
# train.csv           100%[===================>]   1.50M  --.-KB/s    in 0.07s
#
# 2024-05-23 02:14:00 (22.4 MB/s) - ‘train.csv’ saved [1573871/1573871]

# %%
df = pd.read_csv('train.csv')
df.shape
# Out:
# (16800, 2)

# %%
df.columns
# Out:
# Index(['text', 'label'], dtype='object')

# %%
df.head()
# Out:
#                                                 text  label
# 0  rt @user olha quem chegouuuuu, nossos queridin...      0
# 1  veio umas teorias muito loucas na minha cabeça...      1
# 2  @user @user 😂😂😂😂mais nao tinha falado ontem qu...      0
# 3  rt @user quer ser filha da puta logo comigo qu...      1
# 4           vai besta 😂😂😂😂 casquei com a ultima foto      1

# %%
def cleanText(text):
  text = text.encode('ascii', 'ignore').decode('ascii') #remove emojis
  text = re.sub(r'@\w+', '', text) # remove users mentions
  text = re.sub(r'htttps?//\S+', '', text) #remove links
  text = re.sub(r'\s+', ' ', text) #remove extra spaces
  text = re.sub(r'\b(rt|user|https)\b', '', text, flags=re.IGNORECASE)

  return text.strip()

# %%
df['text'] = df['text'].apply(cleanText)

df[['text']].head()
# Out:
#                                                 text
# 0  olha quem chegouuuuu, nossos queridinhos!!! ve...
# 1  veio umas teorias muito loucas na minha cabea ...
# 2  mais nao tinha falado ontem que no ia ser patr...
# 3  quer ser filha da puta logo comigo que sou 50x...
# 4                vai besta casquei com a ultima foto
